# %%
# !apt-get install poppler-utils
# !pip install pdf2image pytesseract pillow opencv-python
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following NEW packages will be installed:
#   poppler-utils
# 0 upgraded, 1 newly installed, 0 to remove and 35 not upgraded.
# Need to get 186 kB of archives.
# After this operation, 697 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 poppler-utils amd64 22.02.0-2ubuntu0.8 [186 kB]
# Fetched 186 kB in 1s (147 kB/s)
# Selecting previously unselected package poppler-utils.
# (Reading database ... 126308 files and directories currently installed.)
# Preparing to unpack .../poppler-utils_22.02.0-2ubuntu0.8_amd64.deb ...
# Unpacking poppler-utils (22.02.0-2ubuntu0.8) ...
# Setting up poppler-utils (22.02.0-2ubuntu0.8) ...
# Processing triggers for man-db (2.10.2-1) ...
# Collecting pdf2image
#   Downloading pdf2image-1.17.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting pytesseract
#   Downloading pytesseract-0.3.13-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (11.2.1)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (4.11.0.86)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.11/dist-packages (from pytesseract) (24.2)
# Requirement already satisfied: numpy>=1.21.2 in /usr/local/lib/python3.11/dist-packages (from opencv-python) (2.0.2)
# Downloading pdf2image-1.17.0-py3-none-any.whl (11 kB)
# Downloading pytesseract-0.3.13-py3-none-any.whl (14 kB)
# Installing collected packages: pytesseract, pdf2image
# Successfully installed pdf2image-1.17.0 pytesseract-0.3.13

# %%
import os
import cv2
import numpy as np
from PIL import Image
import pytesseract
from collections import defaultdict
from pdf2image import convert_from_path

# %%
def convert_pdfs_to_images(pdf_folder, output_image_folder):
    os.makedirs(output_image_folder, exist_ok=True)
    for pdf_file in sorted(os.listdir(pdf_folder)):
        if pdf_file.endswith(".pdf"):
            pdf_path = os.path.join(pdf_folder, pdf_file)
            year = os.path.splitext(pdf_file)[0]
            images = convert_from_path(pdf_path, dpi=300)
            for idx, image in enumerate(images):
                image_filename = f"{year}_page_{idx+1}.png"
                output_path = os.path.join(output_image_folder, image_filename)
                image.save(output_path, "PNG")
                print(f"Saved image: {output_path}")

# %%
convert_pdfs_to_images(pdf_folder="/content/pdf_years", output_image_folder="/content/pdf_images")
# Out:
# Saved image: /content/pdf_images/1904_1787_page_1.png
# Saved image: /content/pdf_images/1905_page_1.png
# Saved image: /content/pdf_images/1906_952_page_1.png
# Saved image: /content/pdf_images/1907_page_1.png
# Saved image: /content/pdf_images/1912_page_1.png
# Saved image: /content/pdf_images/1913_page_1.png
# Saved image: /content/pdf_images/1914_1015_page_1.png
# Saved image: /content/pdf_images/1914_1276_page_1.png
# Saved image: /content/pdf_images/1915_page_1.png
# Saved image: /content/pdf_images/1916_page_1.png
# Saved image: /content/pdf_images/1917_page_1.png
# Saved image: /content/pdf_images/1918_876_page_1.png
# Saved image: /content/pdf_images/1919_905_page_1.png
# Saved image: /content/pdf_images/1920_656_page_1.png
# Saved image: /content/pdf_images/1920_989_page_1.png
# Saved image: /content/pdf_images/1921_1035_page_1.png
# Saved image: /content/pdf_images/1921_342_page_1.png
# Saved image: /content/pdf_images/1922_1008_page_1.png
# Saved image: /content/pdf_images/1923_page_1.png
# Saved image: /content/pdf_images/1924_page_1.png
# Saved image: /content/pdf_images/1926_page_1.png
# Saved image: /content/pdf_images/1927_1120_page_1.png
# Saved image: /content/pdf_images/1927_737_page_1.png
# Saved image: /content/pdf_images/1928_1141_page_1.png
# Saved image: /content/pdf_images/1928_742_page_1.png
# Saved image: /content/pdf_images/1929_1124_page_1.png
# Saved image: /content/pdf_images/1929_735_page_1.png
# Saved image: /content/pdf_images/1930_1353_page_1.png
# Saved image: /content/pdf_images/1930_169_page_1.png
# Saved image: /content/pdf_images/1930_502_page_1.png
# Saved image: /content/pdf_images/1930_753_page_1.png
# Saved image: /content/pdf_images/1931_309_page_1.png
# Saved image: /content/pdf_images/1932_1278_page_1.png
# Saved image: /content/pdf_images/1932_1328_page_1.png
# Saved image: /content/pdf_images/1932_163_page_1.png
# Saved image: /content/pdf_images/1932_768_page_1.png
# Saved image: /content/pdf_images/1934_1383_page_1.png
# Saved image: /content/pdf_images/1935_1176_page_1.png
# Saved image: /content/pdf_images/1935_1384_page_1.png
# Saved image: /content/pdf_images/1935_1438_page_1.png
# Saved image: /content/pdf_images/1936_1215_page_1.png
# Saved image: /content/pdf_images/1936_1432_page_1.png
# Saved image: /content/pdf_images/1937_1534_page_1.png
# Saved image: /content/pdf_images/1937_1594_page_1.png
# Saved image: /content/pdf_images/1937_401_page_1.png
# Saved image: /content/pdf_images/1938_page_1.png
# Saved image: /content/pdf_images/1944_574_page_1.png
# Saved image: /content/pdf_images/1948_page_1.png

# %%
def preprocess_image(image_path):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    if image is None:
        print(f"❌ Failed to load: {image_path}")
        return None

    # Resize
    image = cv2.resize(image, None, fx=2, fy=2, interpolation=cv2.INTER_CUBIC)

    # Contrast
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    enhanced = clahe.apply(image)

    # Blur and threshold
    blurred = cv2.GaussianBlur(enhanced, (3, 3), 0)
    _, otsu = cv2.threshold(blurred, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

    # Morphological clean-up
    kernel_open = np.ones((2, 2), np.uint8)
    opened = cv2.morphologyEx(otsu, cv2.MORPH_OPEN, kernel_open)
    kernel_dilate = np.ones((2, 1), np.uint8)
    dilated = cv2.dilate(opened, kernel_dilate, iterations=1)

    return dilated

# %%
def detect_and_crop_columns(image_path, output_dir, base_filename, min_height_ratio=0.2):
    os.makedirs(output_dir, exist_ok=True)

    # Load image in grayscale
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    if image is None:
        print(f"❌ Cannot load: {image_path}")
        return []

    height, width = image.shape
    min_height = int(min_height_ratio * height)

    # Binarize
    _, binary = cv2.threshold(image, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    # Vertical line detection
    vertical_kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (1, height // 20))
    vertical_lines = cv2.morphologyEx(binary, cv2.MORPH_OPEN, vertical_kernel, iterations=1)

    # Find contours and filter by height
    contours, _ = cv2.findContours(vertical_lines, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
    column_boxes = [cv2.boundingRect(c) for c in contours]
    tall_boxes = [box for box in column_boxes if box[3] >= min_height]
    tall_boxes.sort(key=lambda b: b[0])

    x_coords = [x for (x, y, w, h) in tall_boxes]
    print(f"Tall vertical line x-positions: {x_coords}")

    if not x_coords:
        print(" No tall vertical lines found.")
        return []

    # Find the line closest to center
    center_x = width // 2
    x_cut = min(x_coords, key=lambda x: abs(x - center_x))
    print(f"✅ Splitting at x={x_cut}, nearest to center x={center_x}")

    cropped_paths = []

    # Left column
    left_crop = image[:, 0:x_cut]
    left_path = os.path.join(output_dir, f"{base_filename}_left.png")
    cv2.imwrite(left_path, left_crop)
    cropped_paths.append(left_path)

    # Right column
    right_crop = image[:, x_cut:width]
    right_path = os.path.join(output_dir, f"{base_filename}_right.png")
    cv2.imwrite(right_path, right_crop)
    cropped_paths.append(right_path)

    return cropped_paths

# %%
def ocr_columns(cropped_paths):
    full_text = ""
    for idx, img_path in enumerate(sorted(cropped_paths)):
        img = cv2.imread(img_path)
        if img is None:
            continue
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        _, binary = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)
        column_text = pytesseract.image_to_string(binary, config="--psm 4")
        full_text += f"\n### Column {idx + 1} ({os.path.basename(img_path)}) ###\n{column_text.strip()}\n"
    return full_text

# %%
def process_all_years(input_folder="/content/pdf_images", output_text_folder="/content/ocr_texts", column_crop_root="/content/column_crops"):
    os.makedirs(output_text_folder, exist_ok=True)
    os.makedirs(column_crop_root, exist_ok=True)

    year_to_images = defaultdict(list)
    for image_file in sorted(os.listdir(input_folder)):
        if image_file.lower().endswith(('.png', '.jpg', '.jpeg')):
            year = image_file.split("_")[0]
            year_to_images[year].append(os.path.join(input_folder, image_file))

    print(f"Detected Years: {list(year_to_images.keys())}")

    for year, image_paths in year_to_images.items():
        year_text = ""
        print(f"\n Processing Year: {year} ({len(image_paths)} page(s))")

        for img_path in sorted(image_paths):
            print(f" -  Page: {os.path.basename(img_path)}")

            preprocessed = preprocess_image(img_path)
            if preprocessed is None:
                continue

            page_id = os.path.basename(img_path).split("_")[1]
            column_output_dir = os.path.join(column_crop_root, f"{year}_{page_id}")
            cropped_columns = detect_and_crop_columns(
                img_path,
                output_dir=column_output_dir,
                base_filename=f"{year}_{page_id}"
            )

            if not cropped_columns:
                print(f" Skipping OCR for {img_path} (no columns detected).")
                continue

            page_text = ocr_columns(cropped_columns)
            year_text += f"\n--- Page: {os.path.basename(img_path)} ---\n{page_text}"

        # Save year OCR text
        output_text_path = os.path.join(output_text_folder, f"{year}.txt")
        with open(output_text_path, "w", encoding="utf-8") as f:
            f.write(year_text)
        print(f" Year OCR saved: {output_text_path}")

# %%
process_all_years()
# Out:
# 🔎 Detected Years: ['1904', '1905', '1906', '1907', '1912', '1913', '1914', '1915', '1916', '1917', '1918', '1919', '1920', '1921', '1922', '1923', '1924', '1926', '1927', '1928', '1929', '1930', '1931', '1932', '1934', '1935', '1936', '1937', '1938', '1944', '1948']
#
# 📅 Processing Year: 1904 (1 page(s))
#  - 🖼️ Page: 1904_1787_page_1.png
# ✅ Tall vertical line x-positions: [1016]
# ✅ Splitting at x=1016, nearest to center x=1200
# ✅ Year OCR saved: /content/ocr_texts/1904.txt
#
# 📅 Processing Year: 1905 (1 page(s))
#  - 🖼️ Page: 1905_page_1.png
# ✅ Tall vertical line x-positions: [409, 1371]
# ✅ Splitting at x=1371, nearest to center x=1200
# ✅ Year OCR saved: /content/ocr_texts/1905.txt
#
# 📅 Processing Year: 1906 (1 page(s))
#  - 🖼️ Page: 1906_952_page_1.png
# ✅ Tall vertical line x-positions: [397, 1304]
# ✅ Splitting at x=1304, nearest to center x=1200
# ✅ Year OCR saved: /content/ocr_texts/1906.txt
#
# 📅 Processing Year: 1907 (1 page(s))
#  - 🖼️ Page: 1907_page_1.png
# ✅ Tall vertical line x-positions: [1080, 2013]
# ✅ Splitting at x=1080, nearest to center x=1200
# ✅ Year OCR saved: /content/ocr_texts/1907.txt
#
# 📅 Processing Year: 1912 (1 page(s))
#  - 🖼️ Page: 1912_page_1.png
# ✅ Tall vertical line x-positions: [450, 1387, 1398]
# ✅ Splitting at x=1387, nearest to center x=1200
# ✅ Year OCR saved: /content/ocr_texts/1912.txt
#
# 📅 Processing Year: 1913 (1 page(s))
#  - 🖼️ Page: 1913_page_1.png
# ✅ Tall vertical line x-positions: [1012, 1928, 2222]
# ✅ Splitting at x=1012, nearest to center x=1200
# ✅ Year OCR saved: /content/ocr_texts/1913.txt
#
# 📅 Processing Year: 1914 (2 page(s))
#  - 🖼️ Page: 1914_1015_page_1.png
# ✅ Tall vertical line x-positions: [992, 1869, 1875, 1976, 1988, 2091]
# ✅ Splitting at x=992, nearest to center x=1200
#  - 🖼️ Page: 1914_1276_page_1.png
# ✅ Tall vertical line x-positions: [440, 1318]
# ✅ Splitting at x=1318, nearest to center x=1200
# ✅ Year OCR saved: /content/ocr_texts/1914.txt
#
# 📅 Processing Year: 1915 (1 page(s))
#  - 🖼️ Page: 1915_page_1.png
# ✅ Tall vertical line x-positions: [92, 197, 422, 1358]
# ✅ Splitting at x=1358, nearest to center x=1200
# ✅ Year OCR saved: /content/ocr_texts/1915.txt
#
# 📅 Processing Year: 1916 (1 page(s))
#  - 🖼️ Page: 1916_page_1.png
# ✅ Tall vertical line x-positions: [1975]
# ✅ Splitting at x=1975, nearest to center x=1200
# ✅ Year OCR saved: /content/ocr_texts/1916.txt
#
# 📅 Processing Year: 1917 (1 page(s))
#  - 🖼️ Page: 1917_page_1.png
# ✅ Tall vertical line x-positions: [436, 1340]
# ✅ Splitting at x=1340, nearest to center x=1200
# ✅ Year OCR saved: /content/ocr_texts/1917.txt
#
# 📅 Processing Year: 1918 (1 page(s))
#  - 🖼️ Page: 1918_876_page_1.png
# ✅ Tall vertical line x-positions: [89, 92, 473, 1420]
# ✅ Splitting at x=1420, nearest to center x=1200
# ✅ Year OCR saved: /content/ocr_texts/1918.txt
#
# 📅 Processing Year: 1919 (1 page(s))
#  - 🖼️ Page: 1919_905_page_1.png
# ✅ Tall vertical line x-positions: [976, 1902, 2268]
# ✅ Splitting at x=976, nearest to center x=1200
# ✅ Year OCR saved: /content/ocr_texts/1919.txt
#
# 📅 Processing Year: 1920 (2 page(s))
#  - 🖼️ Page: 1920_656_page_1.png
# ✅ Tall vertical line x-positions: [113, 128, 130, 220, 290, 341, 482, 485, 1417]
# ✅ Splitting at x=1417, nearest to center x=1200
#  - 🖼️ Page: 1920_989_page_1.png
# ✅ Tall vertical line x-positions: [963, 1893, 1909, 1914, 2257]
# ✅ Splitting at x=963, nearest to center x=1275
# ✅ Year OCR saved: /content/ocr_texts/1920.txt
#
# 📅 Processing Year: 1921 (2 page(s))
#  - 🖼️ Page: 1921_1035_page_1.png
# ✅ Tall vertical line x-positions: [967, 1897, 1913, 1930, 1988, 1999, 2120, 2190, 2204, 2280, 2299]
# ✅ Splitting at x=967, nearest to center x=1200
#  - 🖼️ Page: 1921_342_page_1.png
# ✅ Tall vertical line x-positions: [103, 113, 350, 482, 1421]
# ✅ Splitting at x=1421, nearest to center x=1200
# ✅ Year OCR saved: /content/ocr_texts/1921.txt
#
# 📅 Processing Year: 1922 (1 page(s))
#  - 🖼️ Page: 1922_1008_page_1.png
# ✅ Tall vertical line x-positions: [104, 123, 241, 479, 1408]
# ✅ Splitting at x=1408, nearest to center x=1200
# ✅ Year OCR saved: /content/ocr_texts/1922.txt
#
# 📅 Processing Year: 1923 (1 page(s))
#  - 🖼️ Page: 1923_page_1.png
# ✅ Tall vertical line x-positions: [193, 194, 205, 506, 534, 551, 1388, 1391]
# ✅ Splitting at x=1388, nearest to center x=1200
# ✅ Year OCR saved: /content/ocr_texts/1923.txt
#
# 📅 Processing Year: 1924 (1 page(s))
#  - 🖼️ Page: 1924_page_1.png
# ✅ Tall vertical line x-positions: [995, 1860, 1864, 2195, 2202]
# ✅ Splitting at x=995, nearest to center x=1200
# ✅ Year OCR saved: /content/ocr_texts/1924.txt
#
# 📅 Processing Year: 1926 (1 page(s))
#  - 🖼️ Page: 1926_page_1.png
# ✅ Tall vertical line x-positions: [973, 1841, 1876, 2179, 2207]
# ✅ Splitting at x=973, nearest to center x=1200
# ✅ Year OCR saved: /content/ocr_texts/1926.txt
#
# 📅 Processing Year: 1927 (2 page(s))
#  - 🖼️ Page: 1927_1120_page_1.png
# ✅ Tall vertical line x-positions: [187, 200, 527, 536, 1403]
# ✅ Splitting at x=1403, nearest to center x=1200
#  - 🖼️ Page: 1927_737_page_1.png
# ✅ Tall vertical line x-positions: [993, 1859, 1866, 2195, 2200]
# ✅ Splitting at x=993, nearest to center x=1200
# ✅ Year OCR saved: /content/ocr_texts/1927.txt
#
# 📅 Processing Year: 1928 (2 page(s))
#  - 🖼️ Page: 1928_1141_page_1.png
# ✅ Tall vertical line x-positions: [981, 1849, 1862, 2188, 2200]
# ✅ Splitting at x=981, nearest to center x=1200
#  - 🖼️ Page: 1928_742_page_1.png
# ✅ Tall vertical line x-positions: [185, 187, 526, 529, 1399]
# ✅ Splitting at x=1399, nearest to center x=1200
# ✅ Year OCR saved: /content/ocr_texts/1928.txt
#
# 📅 Processing Year: 1929 (2 page(s))
#  - 🖼️ Page: 1929_1124_page_1.png
# ✅ Tall vertical line x-positions: [193, 195, 535, 535, 1397]
# ✅ Splitting at x=1397, nearest to center x=1200
#  - 🖼️ Page: 1929_735_page_1.png
# ✅ Tall vertical line x-positions: [999, 1864, 1870, 2204, 2216]
# ✅ Splitting at x=999, nearest to center x=1200
# ✅ Year OCR saved: /content/ocr_texts/1929.txt
#
# 📅 Processing Year: 1930 (4 page(s))
#  - 🖼️ Page: 1930_1353_page_1.png
# ✅ Tall vertical line x-positions: [742, 751, 1417, 2109]
# ✅ Splitting at x=1417, nearest to center x=1296
#  - 🖼️ Page: 1930_169_page_1.png
# ✅ Tall vertical line x-positions: [784, 1463, 2147, 2154, 2436, 2450]
# ✅ Splitting at x=1463, nearest to center x=1296
#  - 🖼️ Page: 1930_502_page_1.png
# ✅ Tall vertical line x-positions: [106, 119, 403, 417, 1100, 1108, 1778]
# ✅ Splitting at x=1108, nearest to center x=1296
#  - 🖼️ Page: 1930_753_page_1.png
# ✅ Tall vertical line x-positions: [803, 1479, 2168, 2170, 2459, 2461]
# ✅ Splitting at x=1479, nearest to center x=1296
# ✅ Year OCR saved: /content/ocr_texts/1930.txt
#
# 📅 Processing Year: 1931 (1 page(s))
#  - 🖼️ Page: 1931_309_page_1.png
# ✅ Tall vertical line x-positions: [0, 0, 746, 1427, 2114, 2118, 2410, 2413]
# ✅ Splitting at x=1427, nearest to center x=1236
# ✅ Year OCR saved: /content/ocr_texts/1931.txt
#
# 📅 Processing Year: 1932 (4 page(s))
#  - 🖼️ Page: 1932_1278_page_1.png
# ✅ Tall vertical line x-positions: [1321, 1340, 2009, 2028, 2307, 2321]
# ✅ Splitting at x=1321, nearest to center x=1224
#  - 🖼️ Page: 1932_1328_page_1.png
# ✅ Tall vertical line x-positions: [648, 1321, 2003, 2010, 2294, 2305]
# ✅ Splitting at x=1321, nearest to center x=1200
#  - 🖼️ Page: 1932_163_page_1.png
# ✅ Tall vertical line x-positions: [673, 676, 1345, 1351, 2035, 2324]
# ✅ Splitting at x=1345, nearest to center x=1224
#  - 🖼️ Page: 1932_768_page_1.png
# ✅ Tall vertical line x-positions: [1371, 2056, 2071, 2367]
# ✅ Splitting at x=1371, nearest to center x=1236
# ✅ Year OCR saved: /content/ocr_texts/1932.txt
#
# 📅 Processing Year: 1934 (1 page(s))
#  - 🖼️ Page: 1934_1383_page_1.png
# ✅ Tall vertical line x-positions: [832, 837, 1510, 1521, 2199, 2495]
# ✅ Splitting at x=1510, nearest to center x=1350
# ✅ Year OCR saved: /content/ocr_texts/1934.txt
#
# 📅 Processing Year: 1935 (3 page(s))
#  - 🖼️ Page: 1935_1176_page_1.png
# ✅ Tall vertical line x-positions: [176, 178, 346, 475, 1165, 1844]
# ✅ Splitting at x=1165, nearest to center x=1296
#  - 🖼️ Page: 1935_1384_page_1.png
# ✅ Tall vertical line x-positions: [166, 175, 460, 469, 1165]
# ✅ Splitting at x=1165, nearest to center x=1296
#  - 🖼️ Page: 1935_1438_page_1.png
# ✅ Tall vertical line x-positions: [181, 198, 476, 490]
# ✅ Splitting at x=490, nearest to center x=1296
# ✅ Year OCR saved: /content/ocr_texts/1935.txt
#
# 📅 Processing Year: 1936 (2 page(s))
#  - 🖼️ Page: 1936_1215_page_1.png
# ✅ Tall vertical line x-positions: [2160, 2173, 2455, 2465]
# ✅ Splitting at x=2160, nearest to center x=1296
#  - 🖼️ Page: 1936_1432_page_1.png
# ✅ Tall vertical line x-positions: [160, 169, 331, 343, 350]
# ✅ Splitting at x=350, nearest to center x=1296
# ✅ Year OCR saved: /content/ocr_texts/1936.txt
#
# 📅 Processing Year: 1937 (3 page(s))
#  - 🖼️ Page: 1937_1534_page_1.png
# ✅ Tall vertical line x-positions: [81, 94, 379, 391, 1078, 1083, 1756, 1771]
# ✅ Splitting at x=1083, nearest to center x=1235
#  - 🖼️ Page: 1937_1594_page_1.png
# ✅ Tall vertical line x-positions: [100, 105, 400, 1091, 1766]
# ✅ Splitting at x=1091, nearest to center x=1240
#  - 🖼️ Page: 1937_401_page_1.png
# ✅ Tall vertical line x-positions: [709, 1383, 1390, 2074, 2080, 2116, 2290, 2366]
# ✅ Splitting at x=1383, nearest to center x=1232
# ✅ Year OCR saved: /content/ocr_texts/1937.txt
#
# 📅 Processing Year: 1938 (1 page(s))
#  - 🖼️ Page: 1938_page_1.png
# ✅ Tall vertical line x-positions: [0, 709, 1384, 1395, 2059, 2074, 2353, 2370, 2515]
# ✅ Splitting at x=1384, nearest to center x=1260
# ✅ Year OCR saved: /content/ocr_texts/1938.txt
#
# 📅 Processing Year: 1944 (1 page(s))
#  - 🖼️ Page: 1944_574_page_1.png
# ✅ Tall vertical line x-positions: [76, 85, 370, 381, 1088, 1092, 1785]
# ✅ Splitting at x=1092, nearest to center x=1272
# ✅ Year OCR saved: /content/ocr_texts/1944.txt
#
# 📅 Processing Year: 1948 (1 page(s))
#  - 🖼️ Page: 1948_page_1.png
# ✅ Tall vertical line x-positions: [136, 151, 424, 442, 1137, 1137, 1832]
# ✅ Splitting at x=1137, nearest to center x=1308
# ✅ Year OCR saved: /content/ocr_texts/1948.txt

# %%
# !pip install google-generativeai
# Out:
# Requirement already satisfied: google-generativeai in /usr/local/lib/python3.11/dist-packages (0.8.5)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (0.6.15)
# Requirement already satisfied: google-api-core in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.25.1)
# Requirement already satisfied: google-api-python-client in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.173.0)
# Requirement already satisfied: google-auth>=2.15.0 in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.38.0)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (5.29.5)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (2.11.7)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (4.67.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from google-generativeai) (4.14.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /usr/local/lib/python3.11/dist-packages (from google-ai-generativelanguage==0.6.15->google-generativeai) (1.26.1)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core->google-generativeai) (1.70.0)
# Requirement already satisfied: requests<3.0.0,>=2.18.0 in /usr/local/lib/python3.11/dist-packages (from google-api-core->google-generativeai) (2.32.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth>=2.15.0->google-generativeai) (4.9.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from google-api-python-client->google-generativeai) (4.2.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from pydantic->google-generativeai) (0.4.1)
# Requirement already satisfied: grpcio<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.73.0)
# Requirement already satisfied: grpcio-status<2.0.0,>=1.33.2 in /usr/local/lib/python3.11/dist-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai) (1.71.0)
# Requirement already satisfied: pyparsing!=3.0.0,!=3.0.1,!=3.0.2,!=3.0.3,<4,>=2.4.2 in /usr/local/lib/python3.11/dist-packages (from httplib2<1.0.0,>=0.19.0->google-api-python-client->google-generativeai) (3.2.3)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai) (0.6.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3.0.0,>=2.18.0->google-api-core->google-generativeai) (2025.6.15)

# %%
import google.generativeai as genai

genai.configure(api_key="")

# %%
import re

def extract_1807_context(text, window_size=500):
    matches = []

    for match in re.finditer(r'1807', text):
        start = max(match.start() - window_size, 0)
        end = min(match.end() + window_size, len(text))
        context = text[start:end]
        matches.append(context.strip())

    return matches

# %%
with open("/content/ocr_texts/1904.txt", "r", encoding="utf-8") as f:
    ocr_text = f.read()

contexts = extract_1807_context(ocr_text)

for idx, snippet in enumerate(contexts, 1):
    print(f"\n Match {idx}: \n{snippet}\n")
# Out:
#  Match 1:
# --- Page: 1904_1787_page_1.png ---
#
# ### Column 1 (1904_1787_left.png) ###
# DESIGNER:
#
#
#
# PHOTO-ENGI
#
# WIT MINNEAPOLIS ( C
# Witte Max F (Witte Bros), r 1812 n 4th. |
# WITTE OTTO
#
# Bank, Store, Saloon and Office Fix-
# tures, 16-18 Central av, tel T C 1942,
# r 1609 Lyndale av n. (See under Sa-
# loon and Office Fixtures.)
#
# Wittenberg Charles A, tailor The Plym-
# outh, r 260 Humboldt av n.
#
# Witter Davia F, supt of agencies N Ww
# Natl Life Ins Co, r 1807 Dupont ay s.
#
# “Emmett B®, student U of M, b 1807 Du-
# pont av s.
#
# “ Glen F, student, b 1807 Dupont av s.
#
# Wittey Thomas HE, driver Swift & Co, r
#
# : 723 6th av n.
#
# Wittgraf Clara A, b 3102 Blaisdell av.
#
# i. dred A, chf elk M & St L RR, r 911
# n
#
# “ George W, elk Great Western Elev Co,
# b 3102 Blaisdell av.
#
# “ Louis H, slsmn Underwood Typewriter
#
# ' Co, r 2112 27th av s.
#
# * Louis W, mngr Mutual Cigar Store 245
# lst av s, r 8102 Blaisdell av.
#
# “ Pearl A, pleater The New Store, b 3102
# Blaisdell av.
#
# Witt
#
#
#  Match 2:
# --- Page: 1904_1787_page_1.png ---
#
# ### Column 1 (1904_1787_left.png) ###
# DESIGNER:
#
#
#
# PHOTO-ENGI
#
# WIT MINNEAPOLIS ( C
# Witte Max F (Witte Bros), r 1812 n 4th. |
# WITTE OTTO
#
# Bank, Store, Saloon and Office Fix-
# tures, 16-18 Central av, tel T C 1942,
# r 1609 Lyndale av n. (See under Sa-
# loon and Office Fixtures.)
#
# Wittenberg Charles A, tailor The Plym-
# outh, r 260 Humboldt av n.
#
# Witter Davia F, supt of agencies N Ww
# Natl Life Ins Co, r 1807 Dupont ay s.
#
# “Emmett B®, student U of M, b 1807 Du-
# pont av s.
#
# “ Glen F, student, b 1807 Dupont av s.
#
# Wittey Thomas HE, driver Swift & Co, r
#
# : 723 6th av n.
#
# Wittgraf Clara A, b 3102 Blaisdell av.
#
# i. dred A, chf elk M & St L RR, r 911
# n
#
# “ George W, elk Great Western Elev Co,
# b 3102 Blaisdell av.
#
# “ Louis H, slsmn Underwood Typewriter
#
# ' Co, r 2112 27th av s.
#
# * Louis W, mngr Mutual Cigar Store 245
# lst av s, r 8102 Blaisdell av.
#
# “ Pearl A, pleater The New Store, b 3102
# Blaisdell av.
#
# Wittich Mary E (wid James F), b flat 3
# ii Maple.
#
# WIT
#
#
#  Match 3:
# g ---
#
# ### Column 1 (1904_1787_left.png) ###
# DESIGNER:
#
#
#
# PHOTO-ENGI
#
# WIT MINNEAPOLIS ( C
# Witte Max F (Witte Bros), r 1812 n 4th. |
# WITTE OTTO
#
# Bank, Store, Saloon and Office Fix-
# tures, 16-18 Central av, tel T C 1942,
# r 1609 Lyndale av n. (See under Sa-
# loon and Office Fixtures.)
#
# Wittenberg Charles A, tailor The Plym-
# outh, r 260 Humboldt av n.
#
# Witter Davia F, supt of agencies N Ww
# Natl Life Ins Co, r 1807 Dupont ay s.
#
# “Emmett B®, student U of M, b 1807 Du-
# pont av s.
#
# “ Glen F, student, b 1807 Dupont av s.
#
# Wittey Thomas HE, driver Swift & Co, r
#
# : 723 6th av n.
#
# Wittgraf Clara A, b 3102 Blaisdell av.
#
# i. dred A, chf elk M & St L RR, r 911
# n
#
# “ George W, elk Great Western Elev Co,
# b 3102 Blaisdell av.
#
# “ Louis H, slsmn Underwood Typewriter
#
# ' Co, r 2112 27th av s.
#
# * Louis W, mngr Mutual Cigar Store 245
# lst av s, r 8102 Blaisdell av.
#
# “ Pearl A, pleater The New Store, b 3102
# Blaisdell av.
#
# Wittich Mary E (wid James F), b flat 3
# ii Maple.
#
# WITTICH MATT H
#
# Drugegist, 1519 Franklin av e

# %%
import re
import os
import json
import google.generativeai as genai

genai.configure(api_key="")

def extract_1807_context(text, window_size=500):
    matches = []
    for match in re.finditer(r'1807', text):
        start = max(match.start() - window_size, 0)
        end = min(match.end() + window_size, len(text))
        context = text[start:end]
        matches.append(context.strip())
        print(matches)
    return matches

def build_gemini_prompt(year, snippet, target_address="1807 Dupont av s"):
    return f"""
You are a data extraction assistant for historical city directories.

Below is a short OCR text snippet from the {year} Minneapolis city directory:

\"\"\"{snippet}\"\"\"

Step 1: First, does this snippet refer to the address "{target_address}" (allow for minor OCR variations like punctuation, abbreviation, etc.)?
Step 2: If yes, extract these fields (if available):

- Year: {year}
- Full Resident Name
- Spouse Name
- Occupation
- Occupation Address
- Employer
- Address as written in snippet

Strictly output a single JSON object like:

{{
  "year": {year},
  "resident_full_name": "...",
  "spouse_name": "...",
  "occupation": "...",
  "occupation_address":"...",
  "employer": "...",
  "address_in_text": "..."
}}

If the address is not 1807 Dupont Ave S, output: null
"""

def query_gemini(prompt_text):
    model = genai.GenerativeModel('gemini-1.5-pro')
    response = model.generate_content(prompt_text)
    return response.text

def process_year_verify_address(file_path, target_address):
    year = os.path.basename(file_path).replace(".txt", "")
    with open(file_path, "r", encoding="utf-8") as f:
        text = f.read()

    snippets = extract_1807_context(text, window_size=50)
    print(f" {year}: Found {len(snippets)} context snippets with '1807'")

    year_results = []

    for idx, snippet in enumerate(snippets):
        prompt = build_gemini_prompt(year, snippet, target_address)
        gemini_response = query_gemini(prompt)


        year_results.append(gemini_response)

    return year_results

# %%
file_path = "/content/text_files/1938.txt"  # Example year
target_address = "1807 Dupont av s"

results = process_year_verify_address(file_path, target_address)

print(results)
# Out:
# ['. “ Louis, slsmn r1223 Newton av N\n“Mildred maid 1807 Dupont av 8 “ Meyer student r909 Girard av N\n“ Ph']
# ['. “ Louis, slsmn r1223 Newton av N\n“Mildred maid 1807 Dupont av 8 “ Meyer student r909 Girard av N\n“ Ph', "ss dr *“Saml (Rose) h909 Girard av N\n“Vivian maid'1807 Dupont av 8 -|Wainstolk Ann siswn Sally Frocks In"]
#  1938: Found 2 context snippets with '1807'
# ['{\n  "year": 1938,\n  "resident_full_name": "Mildred “",\n  "spouse_name": null,\n  "occupation": "maid",\n  "occupation_address": "1807 Dupont av 8",  \n  "employer": null,\n  "address_in_text": "1807 Dupont av 8"\n}\n', '{\n  "year": 1938,\n  "resident_full_name": "Vivian Wainstolk",\n  "spouse_name": null,\n  "occupation": "maid",\n  "occupation_address": "1807 Dupont av S",\n  "employer": null,\n  "address_in_text": "1807 Dupont av S"\n}\n']

# %%
import json
import os

ocr_text_folder = "/content/text_files"
target_address = "1807 Dupont av s"

all_results = []

for filename in sorted(os.listdir(ocr_text_folder)):
    if filename.endswith(".txt"):
        file_path = os.path.join(ocr_text_folder, filename)
        print(f"\n Processing: {filename}")

        year_results = process_year_verify_address(file_path, target_address)

        # Save results for this year
        output_json_path = os.path.join("/content", f"verified_1807_{filename.replace('.txt', '')}.json")
        with open(output_json_path, "w", encoding="utf-8") as f:
            json.dump(year_results, f, indent=2)
        print(f"Saved year results to: {output_json_path}")

        all_results.extend(year_results)

# Optionally save full combined timeline:
with open("/content/final_timeline_1807.json", "w", encoding="utf-8") as f:
    json.dump(all_results, f, indent=2)
print("\nFull timeline saved: /content/final_timeline_1807.json")
# Out:
#  Processing: 1904.txt
# ['avia F, supt of agencies N Ww\nNatl Life Ins Co, r 1807 Dupont ay s.\n\n“Emmett B®, student U of M, b 1807']
# ['avia F, supt of agencies N Ww\nNatl Life Ins Co, r 1807 Dupont ay s.\n\n“Emmett B®, student U of M, b 1807', '1807 Dupont ay s.\n\n“Emmett B®, student U of M, b 1807 Du-\npont av s.\n\n“ Glen F, student, b 1807 Dupont']
# ['avia F, supt of agencies N Ww\nNatl Life Ins Co, r 1807 Dupont ay s.\n\n“Emmett B®, student U of M, b 1807', '1807 Dupont ay s.\n\n“Emmett B®, student U of M, b 1807 Du-\npont av s.\n\n“ Glen F, student, b 1807 Dupont', 'of M, b 1807 Du-\npont av s.\n\n“ Glen F, student, b 1807 Dupont av s.\n\nWittey Thomas HE, driver Swift & Co']
#  1904: Found 3 context snippets with '1807'
# Saved year results to: /content/verified_1807_1904.json
#
#  Processing: 1905.txt
# ['David F, mngr loan dept N W:°Natl.\nLife Ins Co, r 1807 Dupont av So. |\n“ Emmet E, real est; b 1807 Dupon']
# ['David F, mngr loan dept N W:°Natl.\nLife Ins Co, r 1807 Dupont av So. |\n“ Emmet E, real est; b 1807 Dupon', 'Co, r 1807 Dupont av So. |\n“ Emmet E, real est; b 1807 Dupont av 8,\n* Georgetta, tchr, b 1807 Dunont av']
# ['David F, mngr loan dept N W:°Natl.\nLife Ins Co, r 1807 Dupont av So. |\n“ Emmet E, real est; b 1807 Dupon', 'Co, r 1807 Dupont av So. |\n“ Emmet E, real est; b 1807 Dupont av 8,\n* Georgetta, tchr, b 1807 Dunont av', 'eal est; b 1807 Dupont av 8,\n* Georgetta, tchr, b 1807 Dunont av 8. |\nWitters Nellie G, tehr Central Hig']
#  1905: Found 3 context snippets with '1807'
# Saved year results to: /content/verified_1807_1905.json
#
#  Processing: 1906.txt
# ['t, rentals, loans and fire ins\n205 Andrus bldg, r 1807 Dupont av S.\n\nJAMIESON T A & HUSS CO\n\n(Thomas A J']
#  1906: Found 1 context snippets with '1807'
# Saved year results to: /content/verified_1807_1906.json
#
#  Processing: 1907.txt
# ['entals Loans and Fire Insurance 205\nAndrus Bidg r 1807 Dupont av §$\n\nJAMIESON T A & HUSS CO\n\n(Thomas A J']
#  1907: Found 1 context snippets with '1807'
# Saved year results to: /content/verified_1807_1907.json
#
#  Processing: 1912.txt
#  1912: Found 0 context snippets with '1807'
# Saved year results to: /content/verified_1807_1912.json
#
#  Processing: 1913.txt
# ['ss) pres].\nand sec Towle-Jamieson Investment\nCo r 1807 Dupont av §\n\n“Wm helper b 2748 Blaisdell av\n\n“Wm']
#  1913: Found 1 context snippets with '1807'
# Saved year results to: /content/verified_1807_1913.json
#
#  Processing: 1914.txt
# ['os A pres and sec Towle-Jamieson;\nInvestment Co r 1807 Dupont av §\n“Wm helper South Side Plumbing Co b\n2']
# ['os A pres and sec Towle-Jamieson;\nInvestment Co r 1807 Dupont av §\n“Wm helper South Side Plumbing Co b\n2', 'estment Co vice pres Twin City\nRapid Transit Co r 1807 Dupont av §\n\n“Mrs Jennie M stenogr J H Martin & C']
#  1914: Found 2 context snippets with '1807'
# Saved year results to: /content/verified_1807_1914.json
#
#  Processing: 1915.txt
# ['MAS A PRES AND SEC\nTowle-Jamieson Investment Co r 1807\n= Dupont av §\n“Wm helper b 2748 Blaisdell av\nPHON']
#  1915: Found 1 context snippets with '1807'
# Saved year results to: /content/verified_1807_1915.json
#
#  Processing: 1916.txt
# ['. SEC Washn av S BH\nTowle-Jamiegon Investment Cor 1807! “ Russell e cls Northwestern Nati Bank\nDupont av']
#  1916: Found 1 context snippets with '1807'
# Saved year results to: /content/verified_1807_1916.json
#
#  Processing: 1917.txt
# ['MAS A PRES AND SEC\nTowle-Jamieson Investment Co r 1807\nDupont av 8\n\n“Wm mach Mpls Steel & Mach Co b 2748']
#  1917: Found 1 context snippets with '1807'
# Saved year results to: /content/verified_1807_1917.json
#
#  Processing: 1918.txt
# ['A\n\nPres and Sec Towle-Jamieson Invest-\nment Co r 1807 Dupont av\n\n“Walter hlpr r 26 18th av N Is\n\n“Wm ma']
#  1918: Found 1 context snippets with '1807'
# Saved year results to: /content/verified_1807_1918.json
#
#  Processing: 1919.txt
# ['A\n\nPres and Sec Towle-Jamieson Invest-\nment Co r 1807 Dupont av §\n\n“Wm F service mngr Jenney-Harrington']
#  1919: Found 1 context snippets with '1807'
# Saved year results to: /content/verified_1807_1919.json
#
#  Processing: 1920.txt
# ['VA 7777\n\n \n\nFanning Clara E asst Public Library b\n1807 Dupont av §\n\n“ ioliza beth E salswn Powers b 2913']
# ['VA 7777\n\n \n\nFanning Clara E asst Public Library b\n1807 Dupont av §\n\n“ ioliza beth E salswn Powers b 2913', 'A\n\nPres and Sec Towle-Jamieson Invest-\nment Co r 1807 Dupont av §\n\n“Wm F sales mnegr Perfection Tire Di']
#  1920: Found 2 context snippets with '1807'
# Saved year results to: /content/verified_1807_1920.json
#
#  Processing: 1921.txt
# ['v E\nPres and Sec Towie-Jamieson In-\nvestment Co r 1807 Dupont av §\n“& Huss (Julius J Huss) realtors ins']
# ['v E\nPres and Sec Towie-Jamieson In-\nvestment Co r 1807 Dupont av §\n“& Huss (Julius J Huss) realtors ins', 'v\n\n“Gust N mach r 2012 16th av S’\n\n“Hannah E maid 1807 Dupont av Ss\n\n“ Hart.chauffeur R F Pack\n\n“ Henry']
# ['v E\nPres and Sec Towie-Jamieson In-\nvestment Co r 1807 Dupont av §\n“& Huss (Julius J Huss) realtors ins', 'v\n\n“Gust N mach r 2012 16th av S’\n\n“Hannah E maid 1807 Dupont av Ss\n\n“ Hart.chauffeur R F Pack\n\n“ Henry', 'pls Steel & Mach\nCo r 3003 E Lake\n\n“Jennie M maid 1807 Dupont av S\n\n“Jeremiah H bkpr Intl Harvester Co\nr']
#  1921: Found 3 context snippets with '1807'
# Saved year results to: /content/verified_1807_1921.json
#
#  Processing: 1922.txt
# ['SON THOMAS A\n\nPres Towle-Jamieson Investment Co r\n1807 Dupont av S\n\n“& Huss (Julius J Huss) realtors ins']
#  1922: Found 1 context snippets with '1807'
# Saved year results to: /content/verified_1807_1922.json
#
#  Processing: 1923.txt
# ['SON THOMAS A\n\nPres Towle-Jamieson Investment Co r\n1807 Dupont av §\n\nJAMIESON & HUSS INSURORS\n\nDirectory']
#  1923: Found 1 context snippets with '1807'
# Saved year results to: /content/verified_1807_1923.json
#
#  Processing: 1924.txt
#  1924: Found 0 context snippets with '1807'
# Saved year results to: /content/verified_1807_1924.json
#
#  Processing: 1926.txt
# ['aminer r Hotel\n\nastin\n“ Jennie. Le (wid Thos A) h 1807 Dupont\n\n \n \n\n“ Joseph J supvr dist men Minn Tribu']
#  1926: Found 1 context snippets with '1807'
# Saved year results to: /content/verified_1807_1926.json
#
#  Processing: 1927.txt
# ['nt Co r 4739 1st av S\n\n“« Jennie L Cwid Thos A) h 1807 Dupont\nav\n\n“Lucretia (wid J Watson) r 2440 Blais-']
# ['nt Co r 4739 1st av S\n\n“« Jennie L Cwid Thos A) h 1807 Dupont\nav\n\n“Lucretia (wid J Watson) r 2440 Blais-', 'Fanning Clara E office director Public\nLibrary r 1807 Dupont av 8S\n\n“Eaw h 322 13th av S E\n\n“Eliz E mat']
#  1927: Found 2 context snippets with '1807'
# Saved year results to: /content/verified_1807_1927.json
#
#  Processing: 1928.txt
# ['lant Co r 4739 lst av §\n\n* Jennie, (wid Thos A) h 1807 Dupont\nav\n*“ZLillian stdt r apt B, 1910 lst av S']
# ['lant Co r 4739 lst av §\n\n* Jennie, (wid Thos A) h 1807 Dupont\nav\n*“ZLillian stdt r apt B, 1910 lst av S', 'ens av\n\n“Clara A office director Public Library\nr 1807 Dupont av S\n\n“BRdw real est h 320 18th av S EB\n\n“']
#  1928: Found 2 context snippets with '1807'
# Saved year results to: /content/verified_1807_1928.json
#
#  Processing: 1929 (1).txt
# ['Plant Co r 4739 Ist av S\n\n“Jennie (wid Thos A) h 1807 Dupont\n\nav S$\n\n“John lab h 1806 Chestnut av W\n\n“J']
# ['Plant Co r 4739 Ist av S\n\n“Jennie (wid Thos A) h 1807 Dupont\n\nav S$\n\n“John lab h 1806 Chestnut av W\n\n“J', 'ng the\n\n“Clara A office director Publie Library\nr 1807 Dupont av § pages of the\n“ Edw real est h 320 18t']
#  1929 (1): Found 2 context snippets with '1807'
# Saved year results to: /content/verified_1807_1929 (1).json
#
#  Processing: 1929.txt
# ['Plant Co r 4739 Ist av S\n\n“Jennie (wid Thos A) h 1807 Dupont\n\nav S$\n\n“John lab h 1806 Chestnut av W\n\n“J']
# ['Plant Co r 4739 Ist av S\n\n“Jennie (wid Thos A) h 1807 Dupont\n\nav S$\n\n“John lab h 1806 Chestnut av W\n\n“J', 'ng the\n\n“Clara A office director Publie Library\nr 1807 Dupont av § pages of the\n“ Edw real est h 320 18t']
#  1929: Found 2 context snippets with '1807'
# Saved year results to: /content/verified_1807_1929.json
#
#  Processing: 1930.txt
# ['Levin Bros\nIne h 2644 Marshall\n\nSchnur Eliz cook 1807 Dupont av $§\n\nSchobel Anthony J clk Northland Ele']
# ['Levin Bros\nIne h 2644 Marshall\n\nSchnur Eliz cook 1807 Dupont av $§\n\nSchobel Anthony J clk Northland Ele', 'e A nurse r Hampshire Arms Table Tops\n\n“Rika maid 1807 Dupont av S\n\n“ltobt baker Nordby Baking Co r Rob-']
# ['Levin Bros\nIne h 2644 Marshall\n\nSchnur Eliz cook 1807 Dupont av $§\n\nSchobel Anthony J clk Northland Ele', 'e A nurse r Hampshire Arms Table Tops\n\n“Rika maid 1807 Dupont av S\n\n“ltobt baker Nordby Baking Co r Rob-', 'a Is office director Public Li-\nt ili . : brary r 1807 Dupont av §\nFalmoe dian compt opr Hall Hdw] , Faw']
# ['Levin Bros\nIne h 2644 Marshall\n\nSchnur Eliz cook 1807 Dupont av $§\n\nSchobel Anthony J clk Northland Ele', 'e A nurse r Hampshire Arms Table Tops\n\n“Rika maid 1807 Dupont av S\n\n“ltobt baker Nordby Baking Co r Rob-', 'a Is office director Public Li-\nt ili . : brary r 1807 Dupont av §\nFalmoe dian compt opr Hall Hdw] , Faw', 'dl Eliz (wid Steve) gro 2001 Hen-\nMpls Trust Co r 1807 Dupont av S$ nepin avy apt 42 h do\n“David L firem']
# ['Levin Bros\nIne h 2644 Marshall\n\nSchnur Eliz cook 1807 Dupont av $§\n\nSchobel Anthony J clk Northland Ele', 'e A nurse r Hampshire Arms Table Tops\n\n“Rika maid 1807 Dupont av S\n\n“ltobt baker Nordby Baking Co r Rob-', 'a Is office director Public Li-\nt ili . : brary r 1807 Dupont av §\nFalmoe dian compt opr Hall Hdw] , Faw', 'dl Eliz (wid Steve) gro 2001 Hen-\nMpls Trust Co r 1807 Dupont av S$ nepin avy apt 42 h do\n“David L firem', 's Eliz Jandl r 2001 Hen-\n“Jennie L (wid Thos A) h 1807 Du- nepin av apt 142 h do\npont avS “Lawrence hlpr']
#  1930: Found 5 context snippets with '1807'
# Saved year results to: /content/verified_1807_1930.json
#
#  Processing: 1931.txt
# ['De Muth Bernice sten T K Kelly Sales\n“Susie cook 1807 Dupont av § Sys r2645 Garfield av\n“Ww E eng Dean']
#  1931: Found 1 context snippets with '1807'
# Saved year results to: /content/verified_1807_1931.json
#
#  Processing: 1932.txt
# ['co0 ll\nWahlin Anton h2106 27th av 8\n“Mildred maid 1807 Dupont av S .\nWahll John (Lena) h1219 Morgan av N']
# ['co0 ll\nWahlin Anton h2106 27th av 8\n“Mildred maid 1807 Dupont av S .\nWahll John (Lena) h1219 Morgan av N', '§ “Rachel tchr Girls Vocational High\n“ uebel cook 1807 Dupont av S Sch 1404 W 31st\n“abel Mrs (Wilson-Bac']
# ['co0 ll\nWahlin Anton h2106 27th av 8\n“Mildred maid 1807 Dupont av S .\nWahll John (Lena) h1219 Morgan av N', '§ “Rachel tchr Girls Vocational High\n“ uebel cook 1807 Dupont av S Sch 1404 W 31st\n“abel Mrs (Wilson-Bac', '(Lillie) pkr ri814 S$ 5th\n\nChas A (Muriel) chauf 1807 Dupont] « y 45 D\nav S$ h410 Penn av N apt 3 Doris']
#  1932: Found 3 context snippets with '1807'
# Saved year results to: /content/verified_1807_1932.json
#
#  Processing: 1934.txt
# ['44th\n\nDreher r711 15th av S E av 5\n“Myrtle G maid 1807 Dupont av S “ Rozelle beauty opr r3246 Girard av']
#  1934: Found 1 context snippets with '1807'
# Saved year results to: /content/verified_1807_1934.json
#
#  Processing: 1935.txt
# ['“John A (Alice M) police detective\n“Clara E maid 1807 Dupont av § h4059 Sheridan av N\n“Clarenee A (Esth']
# ['“John A (Alice M) police detective\n“Clara E maid 1807 Dupont av § h4059 Sheridan av N\n“Clarenee A (Esth', '7th av &\ndry) h111134 Hennepin av “Mildred K maid 1807 Dupont av &\n“Sam laundry 8 E 26th r218 8 8th ‘Wah']
# ['“John A (Alice M) police detective\n“Clara E maid 1807 Dupont av § h4059 Sheridan av N\n“Clarenee A (Esth', '7th av &\ndry) h111134 Hennepin av “Mildred K maid 1807 Dupont av &\n“Sam laundry 8 E 26th r218 8 8th ‘Wah', 'LeRoy (Margt) lab h204 Franklin] « Me rtle G maid 1807 Dupont av § — P Tea Co h4227 Longfellow av .\naa a']
#  1935: Found 3 context snippets with '1807'
# Saved year results to: /content/verified_1807_1935.json
#
#  Processing: 1936.txt
# ['gaeter stockmn Sears Roebuck & Col] “Ch ara maid 1807 Dupont av 8\n" 4 illian) jironwkr eMcules jSandage']
# ['gaeter stockmn Sears Roebuck & Col] “Ch ara maid 1807 Dupont av 8\n" 4 illian) jironwkr eMcules jSandage', 'lbert A (Blanche FE) swtchmn N W | * Mildred maid 1807 Dupont av 5\nPaul Bell Tel Co h2914 Upton av N “Vi']
#  1936: Found 2 context snippets with '1807'
# Saved year results to: /content/verified_1807_1936.json
#
#  Processing: 1937.txt
# ['Jean slswn’L_S Donaldson Co ri228\n“Mildred K maid 1807 eapont av § Newton av-N\nWahll see also Wahl and:']
# ['Jean slswn’L_S Donaldson Co ri228\n“Mildred K maid 1807 eapont av § Newton av-N\nWahll see also Wahl and:', '| “ Rosemary. clk 14404 46th av. S\n“Myrtle G maid 1807 Dupont av 8 “ Ross eng Foote Bros Gear & Machine']
# ['Jean slswn’L_S Donaldson Co ri228\n“Mildred K maid 1807 eapont av § Newton av-N\nWahll see also Wahl and:', '| “ Rosemary. clk 14404 46th av. S\n“Myrtle G maid 1807 Dupont av 8 “ Ross eng Foote Bros Gear & Machine', 'T Co\nr4588 Pillsbury av\n\n“Prank M (Clara) earetkr 1807 Dupont\nav S h449 Upton av §\n\n“Fred J (Hazel A) ch']
#  1937: Found 3 context snippets with '1807'
# Saved year results to: /content/verified_1807_1937.json
#
#  Processing: 1938.txt
# ['. “ Louis, slsmn r1223 Newton av N\n“Mildred maid 1807 Dupont av 8 “ Meyer student r909 Girard av N\n“ Ph']
# ['. “ Louis, slsmn r1223 Newton av N\n“Mildred maid 1807 Dupont av 8 “ Meyer student r909 Girard av N\n“ Ph', "ss dr *“Saml (Rose) h909 Girard av N\n“Vivian maid'1807 Dupont av 8 -|Wainstolk Ann siswn Sally Frocks In"]
#  1938: Found 2 context snippets with '1807'
# Saved year results to: /content/verified_1807_1938.json
#
#  Processing: 1944.txt
# ['42d\n\nJamieson Carson F (Margt B; Jamieson & Co) h\n1807 Dupont av 8\n\n"Clayton F (Mollie) burner Northern']
#  1944: Found 1 context snippets with '1807'
# Saved year results to: /content/verified_1807_1944.json
#
#  Processing: 1948.txt
# ['evens\nCarson F (Margt B; Jamieson & Company) h av\n1807 Dupont av S " Archibald W (Lillian E) trucker Car']
#  1948: Found 1 context snippets with '1807'
# Saved year results to: /content/verified_1807_1948.json
#
# Full timeline saved: /content/final_timeline_1807.json
